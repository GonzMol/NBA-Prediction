# %%
import requests
import json
from dateutil import parser
import pandas as pd
import time
import math
import matplotlib.pyplot as plt
import pickle
import seaborn as sb
import numpy as np
API_KEY = 'e22c0224c5f98375d85a94c35b0f1e05'
API_KEY = 'eb749887d82b13b877b1d6ec66a76e62'

# %%
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 
#
# First get a list of in-season sports
#   The sport 'key' from the response can be used to get odds in the next request
#
# # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # # 

sports_response = requests.get(
    'https://api.the-odds-api.com/v4/sports', 
    params={
        'api_key': API_KEY
    }
)

# %%
sportList = list()
for sport in sports_response.json():
    sportList.append(sport['key'])

# %%
print(sportList)
# Out:
# ['americanfootball_ncaaf', 'americanfootball_nfl_super_bowl_winner', 'aussierules_afl', 'baseball_mlb_preseason', 'baseball_mlb_world_series_winner', 'basketball_euroleague', 'basketball_nba', 'basketball_nba_championship_winner', 'basketball_ncaab', 'cricket_ipl', 'cricket_odi', 'cricket_psl', 'cricket_test_match', 'golf_masters_tournament_winner', 'golf_pga_championship_winner', 'golf_the_open_championship_winner', 'golf_us_open_winner', 'icehockey_nhl', 'icehockey_nhl_championship_winner', 'icehockey_sweden_allsvenskan', 'icehockey_sweden_hockey_league', 'mma_mixed_martial_arts', 'rugbyleague_nrl', 'soccer_argentina_primera_division', 'soccer_australia_aleague', 'soccer_austria_bundesliga', 'soccer_belgium_first_div', 'soccer_conmebol_copa_libertadores', 'soccer_denmark_superliga', 'soccer_efl_champ', 'soccer_england_league1', 'soccer_england_league2', 'soccer_epl', 'soccer_fa_cup', 'soccer_france_ligue_one', 'soccer_france_ligue_two', 'soccer_germany_bundesliga', 'soccer_germany_bundesliga2', 'soccer_germany_liga3', 'soccer_greece_super_league', 'soccer_italy_serie_a', 'soccer_italy_serie_b', 'soccer_japan_j_league', 'soccer_korea_kleague1', 'soccer_league_of_ireland', 'soccer_mexico_ligamx', 'soccer_netherlands_eredivisie', 'soccer_norway_eliteserien', 'soccer_poland_ekstraklasa', 'soccer_portugal_primeira_liga', 'soccer_spain_la_liga', 'soccer_spain_segunda_division', 'soccer_spl', 'soccer_sweden_allsvenskan', 'soccer_sweden_superettan', 'soccer_switzerland_superleague', 'soccer_turkey_super_league', 'soccer_uefa_champs_league', 'soccer_uefa_europa_conference_league', 'soccer_uefa_europa_league', 'soccer_uefa_nations_league', 'soccer_usa_mls']

# %%
SPORT = 'icehockey_nhl' # use the sport_key from the /sports endpoint below, or use 'upcoming' to see the next 8 games across all sports

# sportList = ['basketball_nba']

# sportList = ['basketball_nba']
for sport in sportList:
    print(sport)
    # if ('winner' in sport.lower()) or ('icehockey_sweden' in sport.lower()) or ('aussierules' in sport.lower()) or ('cricket' in sport.lower()) or ('mma_mixed' in sport.lower()):
    #     pass
    if ('winner' in sport.lower()):
        print('skip')
        pass
    else:
        
        
        REGIONS = 'au' # uk | us | eu | au. Multiple can be specified if comma delimited

        MARKETS = 'h2h' # h2h | spreads | totals. Multiple can be specified if comma delimited

        ODDS_FORMAT = 'decimal' # decimal | american

        DATE_FORMAT = 'iso' # iso | unix


        odds_response = requests.get(
            f'https://api.the-odds-api.com/v4/sports/{sport}/odds',
            params={
                'api_key': API_KEY,
                'regions': REGIONS,
                'markets': MARKETS,
                'oddsFormat': ODDS_FORMAT,
                'dateFormat': DATE_FORMAT,
            }
        )

        odds_json = odds_response.json()

        for gameIndex in range(len(odds_json)):
            index_zero = list()
            index_one = list()
            index_two = list()
            for book in odds_json[gameIndex]['bookmakers']:
                if book['title'] != 'Betfair':
                    if len(book['markets'][0]['outcomes']) == 2:
                        index_zero.append(book['markets'][0]['outcomes'][0]['price'])
                        index_one.append(book['markets'][0]['outcomes'][1]['price'])
                    if len(book['markets'][0]['outcomes']) == 3:
                        index_zero.append(book['markets'][0]['outcomes'][0]['price'])
                        index_one.append(book['markets'][0]['outcomes'][1]['price'])
                        index_two.append(book['markets'][0]['outcomes'][2]['price'])
            
            if not index_zero:
                break
                
            if len(book['markets'][0]['outcomes']) == 2:
                outcome = (1/max(index_zero)) + 1/max(index_one)
            # if len(book['markets'][0]['outcomes']) == 3:
            #     outcome = (1/max(index_zero)) + 1/max(index_one) + 1/max(index_two)
            if outcome < 1:
                print(outcome)
                for book in odds_json[gameIndex]['bookmakers']:
                    if book['title'] != 'Betfair':
                        print(book['title'] + ': ')
                        print(book['markets'][0])       
            print()
    time.sleep(2)
# Out:
# americanfootball_ncaaf
# americanfootball_nfl_super_bowl_winner
# skip
# aussierules_afl
#
#
#
#
#
#
#
#
#
# baseball_mlb_preseason
# baseball_mlb_world_series_winner
# skip
# basketball_euroleague
#
#
#
#
#
#
#
#
#
# basketball_nba
#
#
#
#
#
#
#
# basketball_nba_championship_winner
# skip
# basketball_ncaab
#
# cricket_ipl
#
#
#
#
#
# cricket_odi
#
# cricket_psl
#
#
# cricket_test_match
#
#
#
#
# golf_masters_tournament_winner
# skip
# golf_pga_championship_winner
# skip
# golf_the_open_championship_winner
# skip
# golf_us_open_winner
# skip
# icehockey_nhl
#
#
#
#
#
#
# icehockey_nhl_championship_winner
# skip
# icehockey_sweden_allsvenskan
# 0.8611863896416742
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Djurgårdens IF', 'price': 1.62}, {'name': 'Tingsryds AIF', 'price': 4.1}, {'name': 'Draw', 'price': 5.0}]}
# Ladbrokes:
# {'key': 'h2h', 'last_update': '2023-03-06T05:09:46Z', 'outcomes': [{'name': 'Djurgårdens IF', 'price': 1.33}, {'name': 'Tingsryds AIF', 'price': 3.0}]}
# Neds:
# {'key': 'h2h', 'last_update': '2023-03-06T05:09:46Z', 'outcomes': [{'name': 'Djurgårdens IF', 'price': 1.33}, {'name': 'Tingsryds AIF', 'price': 3.0}]}
#
# 0.8611863896416742
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'AIK', 'price': 2.8}, {'name': 'HC Vita Hästen', 'price': 2.14}, {'name': 'Draw', 'price': 4.25}]}
#
# 0.8611863896416742
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Almtuna IS', 'price': 1.71}, {'name': 'Östersunds IK', 'price': 4.0}, {'name': 'Draw', 'price': 4.35}]}
#
# 0.8611863896416742
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'BIK Karlskoga', 'price': 1.66}, {'name': 'Kristianstads IK', 'price': 4.0}, {'name': 'Draw', 'price': 4.7}]}
#
# 0.8611863896416742
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'IF Björklöven', 'price': 1.18}, {'name': 'Västerviks IK', 'price': 11.0}, {'name': 'Draw', 'price': 8.0}]}
#
# 0.8611863896416742
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Modo Hockey', 'price': 1.75}, {'name': 'Södertälje SK', 'price': 3.75}, {'name': 'Draw', 'price': 4.4}]}
#
# 0.8611863896416742
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Mora IK', 'price': 2.14}, {'name': 'Västerås IK', 'price': 2.75}, {'name': 'Draw', 'price': 4.35}]}
#
# icehockey_sweden_hockey_league
# 0.8244199440513411
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:09:21Z', 'outcomes': [{'name': 'Brynäs IF', 'price': 2.95}, {'name': 'Timrå IK', 'price': 2.06}, {'name': 'Draw', 'price': 4.2}]}
# Ladbrokes:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Brynäs IF', 'price': 2.2}, {'name': 'Timrå IK', 'price': 1.62}]}
# Neds:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Brynäs IF', 'price': 2.2}, {'name': 'Timrå IK', 'price': 1.62}]}
#
# 0.8211650180562098
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:09:21Z', 'outcomes': [{'name': 'Frölunda HC', 'price': 1.93}, {'name': 'IK Oskarshamn', 'price': 3.3}, {'name': 'Draw', 'price': 4.1}]}
# Ladbrokes:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Frölunda HC', 'price': 1.6}, {'name': 'IK Oskarshamn', 'price': 2.2}]}
# Neds:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Frölunda HC', 'price': 1.6}, {'name': 'IK Oskarshamn', 'price': 2.2}]}
#
# 0.8210180623973727
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:09:21Z', 'outcomes': [{'name': 'Färjestad BK', 'price': 2.1}, {'name': 'Luleå HF', 'price': 2.9}, {'name': 'Draw', 'price': 4.1}]}
# Ladbrokes:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Färjestad BK', 'price': 1.62}, {'name': 'Luleå HF', 'price': 2.2}]}
# Neds:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Färjestad BK', 'price': 1.62}, {'name': 'Luleå HF', 'price': 2.2}]}
#
# 0.8181818181818181
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:09:21Z', 'outcomes': [{'name': 'HV71', 'price': 2.75}, {'name': 'Skellefteå AIK', 'price': 2.2}, {'name': 'Draw', 'price': 4.1}]}
# Ladbrokes:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'HV71', 'price': 2.05}, {'name': 'Skellefteå AIK', 'price': 1.7}]}
# Neds:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'HV71', 'price': 2.05}, {'name': 'Skellefteå AIK', 'price': 1.7}]}
#
# 0.8597837460760377
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:09:21Z', 'outcomes': [{'name': 'Leksands IF', 'price': 1.88}, {'name': 'Malmö Redhawks', 'price': 3.05}, {'name': 'Draw', 'price': 4.3}]}
# Ladbrokes:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Leksands IF', 'price': 1.62}, {'name': 'Malmö Redhawks', 'price': 2.2}]}
# Neds:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Leksands IF', 'price': 1.62}, {'name': 'Malmö Redhawks', 'price': 2.2}]}
#
# 0.8433402346445824
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:09:21Z', 'outcomes': [{'name': 'Linköping HC', 'price': 4.5}, {'name': 'Växjö Lakers', 'price': 1.61}, {'name': 'Draw', 'price': 4.6}]}
# Ladbrokes:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Linköping HC', 'price': 2.75}, {'name': 'Växjö Lakers', 'price': 1.4}]}
# Neds:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Linköping HC', 'price': 2.75}, {'name': 'Växjö Lakers', 'price': 1.4}]}
#
# 0.8265993265993266
# Unibet:
# {'key': 'h2h', 'last_update': '2023-03-06T05:09:21Z', 'outcomes': [{'name': 'Rögle BK', 'price': 2.75}, {'name': 'Örebro HK', 'price': 2.16}, {'name': 'Draw', 'price': 4.25}]}
# Ladbrokes:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Rögle BK', 'price': 2.15}, {'name': 'Örebro HK', 'price': 1.65}]}
# Neds:
# {'key': 'h2h', 'last_update': '2023-03-06T05:10:31Z', 'outcomes': [{'name': 'Rögle BK', 'price': 2.15}, {'name': 'Örebro HK', 'price': 1.65}]}
#
# mma_mixed_martial_arts
#
#
#
#
#
#
#
#
#
#
#
# rugbyleague_nrl
#
#
#
#
#
#
#
#
# soccer_argentina_primera_division
#
#
#
#
#
#
#
#
# soccer_australia_aleague
#
#
#
#
#
#
#
#
#
#
#
# soccer_austria_bundesliga
#
#
#
#
#
#
# soccer_belgium_first_div
#
#
#
#
#
#
#
#
#
# soccer_conmebol_copa_libertadores
#
#
#
#
# soccer_denmark_superliga
#
#
#
#
#
#
#
# soccer_efl_champ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soccer_england_league1
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soccer_england_league2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soccer_epl
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soccer_fa_cup
#
#
#
#
# soccer_france_ligue_one
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soccer_france_ligue_two
#
#
#
#
#
#
#
#
#
#
# soccer_germany_bundesliga
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soccer_germany_bundesliga2
#
#
#
#
#
#
# soccer_germany_liga3
#
#
# soccer_greece_super_league
#
#
#
#
#
#
#
#
# soccer_italy_serie_a
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soccer_italy_serie_b
#
#
#
#
#
#
#
#
#
#
#
# soccer_japan_j_league
#
#
#
#
#
#
#
#
#
# soccer_korea_kleague1
#
#
#
#
#
#
# soccer_league_of_ireland
#
#
#
#
#
# soccer_mexico_ligamx
#
#
#
#
#
#
#
#
#
# soccer_netherlands_eredivisie
#
#
#
#
#
#
#
#
#
# soccer_norway_eliteserien
#
#
#
#
#
#
#
#
# soccer_poland_ekstraklasa
#
#
#
#
#
#
#
#
#
#
# soccer_portugal_primeira_liga
#
#
#
#
#
#
#
#
#
#
# soccer_spain_la_liga
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# soccer_spain_segunda_division
#
#
#
#
#
#
#
#
#
#
#
# soccer_spl
#
#
#
# soccer_sweden_allsvenskan
#
#
#
#
#
#
#
#
# soccer_sweden_superettan
#
#
#
#
#
#
#
#
# soccer_switzerland_superleague
#
#
#
#
#
# soccer_turkey_super_league
#
#
#
#
#
#
# soccer_uefa_champs_league
#
#
#
#
#
#
#
#
# soccer_uefa_europa_conference_league
#
#
#
#
#
#
#
#
# soccer_uefa_europa_league
#
#
#
#
#
#
#
#
# soccer_uefa_nations_league
#
#
# soccer_usa_mls

# %%
print('Remaining requests', odds_response.headers['x-requests-remaining'])
print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# Remaining requests 391
# Used requests 109

# %%
sportList = ['basketball_nba']

# sportList = ['basketball_nba']
for sport in sportList:
    print(sport)
    # if ('winner' in sport.lower()) or ('icehockey_sweden' in sport.lower()) or ('aussierules' in sport.lower()) or ('cricket' in sport.lower()) or ('mma_mixed' in sport.lower()):
    #     pass
    if ('winner' in sport.lower()):
        print('skip')
        pass
    else:
        
        
        REGIONS = 'au' # uk | us | eu | au. Multiple can be specified if comma delimited

        MARKETS = 'h2h' # h2h | spreads | totals. Multiple can be specified if comma delimited

        ODDS_FORMAT = 'decimal' # decimal | american

        DATE_FORMAT = 'iso' # iso | unix


        odds_response = requests.get(
            f'https://api.the-odds-api.com/v4/sports/{sport}/odds',
            params={
                'api_key': API_KEY,
                'regions': REGIONS,
                'markets': MARKETS,
                'oddsFormat': ODDS_FORMAT,
                'dateFormat': DATE_FORMAT,
            }
        )

        odds_json = odds_response.json()

                
        for gameIndex in range(len(odds_json)):
            index_zero = list()
            index_one = list()
            index_two = list()
            for book in odds_json[gameIndex]['bookmakers']:
                if book['title'] != 'Betfair':
                    if len(book['markets'][0]['outcomes']) == 2:
                        index_zero.append(book['markets'][0]['outcomes'][0]['price'])
                        index_one.append(book['markets'][0]['outcomes'][1]['price'])
                    if len(book['markets'][0]['outcomes']) == 3:
                        index_zero.append(book['markets'][0]['outcomes'][0]['price'])
                        index_one.append(book['markets'][0]['outcomes'][1]['price'])
                        index_two.append(book['markets'][0]['outcomes'][2]['price'])
            
            if not index_zero:
                break
                
            if len(book['markets'][0]['outcomes']) == 2:
                outcome = (1/max(index_zero)) + 1/max(index_one)
            # if len(book['markets'][0]['outcomes']) == 3:
            #     outcome = (1/max(index_zero)) + 1/max(index_one) + 1/max(index_two)
            if outcome < 1:
                print(outcome)
                for book in odds_json[gameIndex]['bookmakers']:
                    if book['title'] != 'Betfair':
                        print(book['title'] + ': ')
                        print(book['markets'][0])       
            print()
    time.sleep(2)
# Out:
# basketball_nba
